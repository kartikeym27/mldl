# %%
# expt 2

import pandas as pd
import numpy as np


df = pd.read_csv("/content/drive/MyDrive/heart.csv")


from google.colab import drive
drive.mount('/content/drive')


import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import numpy as np


# Assuming df is already loaded
x = df[['age', 'sex', 'chol', 'cp', 'fbs', 'thalach', 'target']]
x1 = x[0:75]
x2 = x[76:150]
x3 = x[151:227]
x4 = x[228:302]


# Save splits to CSV (if needed)
x1.to_csv('tst.csv', index=False)
x2.to_csv('tr1-a.csv', index=False)
x3.to_csv('tr2-b.csv', index=False)
x4.to_csv('tr3-c.csv', index=False)


# Prepare features and target
features = ['age', 'sex', 'chol', 'cp', 'fbs', 'thalach']
target = 'target'


X1 = x1[features]
y1 = x1[target]


X2 = x2[features]
y2 = x2[target]


X3 = x3[features]
y3 = x3[target]


X4 = x4[features]
y4 = x4[target]


# Train models
model1 = DecisionTreeClassifier()
model2 = DecisionTreeClassifier()
model3 = DecisionTreeClassifier()


model1.fit(X2, y2)
model2.fit(X3, y3)
model3.fit(X4, y4)


# Make predictions
pred1 = model1.predict(X1)
pred2 = model2.predict(X1)
pred3 = model3.predict(X1)


# Calculate accuracy and error for each model
accuracy1 = accuracy_score(y1, pred1)
error1 = 1 - accuracy1


accuracy2 = accuracy_score(y1, pred2)
error2 = 1 - accuracy2


accuracy3 = accuracy_score(y1, pred3)
error3 = 1 - accuracy3


# Majority vote
predictions = np.array([pred1, pred2, pred3])
majority_vote = np.apply_along_axis(lambda x: np.bincount(x).argmax(), axis=0, arr=predictions)


# Evaluate performance of the majority vote model
majority_vote_accuracy = accuracy_score(y1, majority_vote)
majority_vote_error = 1 - majority_vote_accuracy


# Print results
print(f'Model 1 - Accuracy: {accuracy1}, Error: {error1}')
print(f'Model 2 - Accuracy: {accuracy2}, Error: {error2}')
print(f'Model 3 - Accuracy: {accuracy3}, Error: {error3}')
print(f'Majority Vote Model - Accuracy: {majority_vote_accuracy}, Error: {majority_vote_error}')


import pandas as pd
import numpy as np


df = pd.read_csv("/content/drive/MyDrive/heart.csv")


from google.colab import drive
drive.mount('/content/drive')


df


import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import numpy as np


# Assuming df is already loaded
x = df[['age', 'sex', 'chol', 'cp', 'fbs', 'thalach', 'target']]
x1 = x[0:75]
x2 = x[76:150]
x3 = x[151:227]
x4 = x[228:302]


# Save splits to CSV (if needed)
x1.to_csv('tst.csv', index=False)
x2.to_csv('tr1-a.csv', index=False)
x3.to_csv('tr2-b.csv', index=False)
x4.to_csv('tr3-c.csv', index=False)


# Prepare features and target
features = ['age', 'sex', 'chol', 'cp', 'fbs', 'thalach']
target = 'target'


X1 = x1[features]
y1 = x1[target]


X2 = x2[features]
y2 = x2[target]


X3 = x3[features]
y3 = x3[target]


X4 = x4[features]
y4 = x4[target]


# Train models
model1 = DecisionTreeClassifier()
model2 = DecisionTreeClassifier()
model3 = DecisionTreeClassifier()


model1.fit(X2, y2)
model2.fit(X3, y3)
model3.fit(X4, y4)


# Make predictions
pred1 = model1.predict(X1)
pred2 = model2.predict(X1)
pred3 = model3.predict(X1)


# Calculate accuracy and error for each model
accuracy1 = accuracy_score(y1, pred1)
error1 = 1 - accuracy1


accuracy2 = accuracy_score(y1, pred2)
error2 = 1 - accuracy2


accuracy3 = accuracy_score(y1, pred3)
error3 = 1 - accuracy3


# Majority vote
predictions = np.array([pred1, pred2, pred3])
majority_vote = np.apply_along_axis(lambda x: np.bincount(x).argmax(), axis=0, arr=predictions)


# Evaluate performance of the majority vote model
majority_vote_accuracy = accuracy_score(y1, majority_vote)
majority_vote_error = 1 - majority_vote_accuracy


# Print results
print(f'Model 1 - Accuracy: {accuracy1}, Error: {error1}')
print(f'Model 2 - Accuracy: {accuracy2}, Error: {error2}')
print(f'Model 3 - Accuracy: {accuracy3}, Error: {error3}')
print(f'Majority Vote Model - Accuracy: {majority_vote_accuracy}, Error: {majority_vote_error}')


from sklearn.model_selection import train_test_split


X = df.drop('target', axis=1)


y = df['target']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


from sklearn.tree import DecisionTreeClassifier


model_dt = DecisionTreeClassifier()
model_dt.fit(X_train,y_train)


from sklearn.tree import DecisionTreeClassifier
x3


pred_dt = model_dt.predict(X_test)


dt = accuracy_score(y_test, pred_dt)
print(dt)


# Commented out IPython magic to ensure Python compatibility.
import pandas as pd
import time
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report


cm = confusion_matrix(y_test, pred_dt)
sns.heatmap(cm/np.sum(cm), annot = True, fmt=  '0.2%', cmap = "Reds")


best_acc = max(dt,majority_vote_accuracy)
best_acc


df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 import pandas as pd
#       2 import numpy as np
# ----> 5 df = pd.read_csv("/content/drive/MyDrive/heart.csv")
#       8 from google.colab import drive
#       9 drive.mount('/content/drive')
#
# ...
